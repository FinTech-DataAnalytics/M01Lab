# %% [markdown]
# <a href="https://colab.research.google.com/github/skipperjay/M01Lab/blob/main/SewellLab1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import yfinance as yf

# %%
df = yf.download("AAPL",
                 start="2011-01-01",
                 end="2021-12-31",
                 progress=False)
# Out:
# /tmp/ipython-input-3131278277.py:1: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   df = yf.download("AAPL",

# %%
print(f"Downloaded {len(df)} rows of data.")
df
# Out:
# Downloaded 2768 rows of data.
# Price            Close        High         Low        Open     Volume
# Ticker            AAPL        AAPL        AAPL        AAPL       AAPL
# Date
# 2011-01-03    9.884150    9.904843    9.742292    9.766285  445138400
# 2011-01-04    9.935734    9.972023    9.841561    9.970223  309080800
# 2011-01-05   10.017004   10.027201    9.882044    9.883544  255519600
# 2011-01-06   10.008909   10.054495    9.984016   10.038600  300428800
# 2011-01-07   10.080591   10.087489    9.954028   10.016710  311931200
# ...                ...         ...         ...         ...        ...
# 2021-12-23  172.658020  173.216316  171.668778  172.236862   68356600
# 2021-12-27  176.624832  176.712979  173.431819  173.451398   74919600
# 2021-12-28  175.606186  177.604279  174.861807  176.458320   79144300
# 2021-12-29  175.694382  176.918699  174.479854  175.645406   62348900
# 2021-12-30  174.538559  176.859873  174.430819  175.782469   59773000
#
# ...

# %%
aapl_data = yf.Ticker("AAPL")

# %%
aapl_data.history()
# Out:
#                                  Open        High         Low       Close  \
# Date
# 2025-12-24 00:00:00-05:00  272.339996  275.429993  272.200012  273.809998
# 2025-12-26 00:00:00-05:00  274.160004  275.369995  272.859985  273.399994
# 2025-12-29 00:00:00-05:00  272.690002  274.359985  272.350006  273.760010
# 2025-12-30 00:00:00-05:00  272.809998  274.079987  272.279999  273.079987
# 2025-12-31 00:00:00-05:00  273.059998  273.679993  271.750000  271.859985
# 2026-01-02 00:00:00-05:00  272.260010  277.839996  269.000000  271.010010
# 2026-01-05 00:00:00-05:00  270.640015  271.510010  266.140015  267.260010
# 2026-01-06 00:00:00-05:00  267.000000  267.549988  262.119995  262.359985
# 2026-01-07 00:00:00-05:00  263.200012  263.679993  259.809998  260.329987
# 2026-01-08 00:00:00-05:00  257.019989  259.290009  255.699997  259.040009
# 2026-01-09 00:00:00-05:00  259.079987  260.209991  256.220001  259.369995
# 2026-01-12 00:00:00-05:00  259.160004  261.299988  256.799988  260.250000
# ...

# %%
pip install Quandl

# %%
# !pip install nasdaq-data-link

# %%
import pandas as pd
import nasdaqdatalink

# %%
nasdaqdatalink.ApiConfig.api_key = "8yybVbpyxWk6ZpDXhhTs"

df = nasdaqdatalink.get(
    "WIKI/AAPL", rows=5
)
# Out:
# ---------------------------------------------------------------------------
# JSONDecodeError                           Traceback (most recent call last)
# /usr/local/lib/python3.12/dist-packages/requests/models.py in json(self, **kwargs)
#     975         try:
# --> 976             return complexjson.loads(self.text, **kwargs)
#     977         except JSONDecodeError as e:
#
# /usr/local/lib/python3.12/dist-packages/simplejson/__init__.py in loads(s, encoding, cls, object_hook, parse_float, parse_int, parse_constant, object_pairs_hook, use_decimal, allow_nan, **kw)
#     513             and not use_decimal and not allow_nan and not kw):
# --> 514         return _default_decoder.decode(s)
#     515     if cls is None:
#
# /usr/local/lib/python3.12/dist-packages/simplejson/decoder.py in decode(self, s, _w, _PY3)
#     385             s = str(s, self.encoding)
# --> 386         obj, end = self.raw_decode(s)
#     387         end = _w(s, end).end()
#
# ...

# %%
# !pip install intrinio-sdk
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.2/1.2 MB 16.7 MB/s eta 0:00:00
# ...

# %%
import intrinio_sdk as intrinio
import pandas as pd

# %%
intrinio.ApiClient().set_api_key("Ojk5NDc4ZGE0ODdkNGJjYmJmZjg2ZDE5ZGU0MmQ3OWEx")
security_api = intrinio.SecurityApi()

# %%
r = security_api.get_security_stock_prices(
    identifier="AAPL",
    start_date="2011-01-01",
    end_date="2021-12-31",
    frequency="daily",
    page_size=10000
)
# Out:
# ---------------------------------------------------------------------------
# ApiException                              Traceback (most recent call last)
# /tmp/ipython-input-3346059308.py in <cell line: 0>()
# ----> 1 r = security_api.get_security_stock_prices(
#       2     identifier="AAPL",
#       3     start_date="2011-01-01",
#       4     end_date="2021-12-31",
#       5     frequency="daily",
#
# /usr/local/lib/python3.12/dist-packages/intrinio_sdk/api/security_api.py in get_security_stock_prices(self, identifier, **kwargs)
#    6495             return self.get_security_stock_prices_with_http_info(identifier, **kwargs)  # noqa: E501
#    6496         else:
# -> 6497             (data) = self.get_security_stock_prices_with_http_info(identifier, **kwargs)  # noqa: E501
#    6498             return data
#    6499
#
# /usr/local/lib/python3.12/dist-packages/intrinio_sdk/api/security_api.py in get_security_stock_prices_with_http_info(self, identifier, **kwargs)
# ...

# %%
# !pip install alpha_vantage

# %%
from alpha_vantage.cryptocurrencies import CryptoCurrencies

# %%
ALPHA_VANTAGE_API_KEY = "DJU7G3TSMOLW0H25"
crypto_api = CryptoCurrencies(key=ALPHA_VANTAGE_API_KEY,
                              output_format= "pandas")

# %%
data, meta_data = crypto_api.get_digital_currency_daily(
    symbol="BTC",
    market="EUR"
)

# %%
crypto_api.get_digital_currency_exchange_rate(
    from_currency="BTC",
    to_currency="USD"
)[0].transpose()
# Out:
#                       Realtime Currency Exchange Rate
# 1. From_Currency Code                             BTC
# 2. From_Currency Name                         Bitcoin
# 3. To_Currency Code                               USD
# 4. To_Currency Name              United States Dollar
# 5. Exchange Rate                       86413.97000000
# 6. Last Refreshed                 2026-01-25 23:37:03
# 7. Time Zone                                      UTC
# 8. Bid Price                           86412.28000000
# 9. Ask Price                           86414.80300000

# %%
import requests
import pandas as pd
from io import BytesIO

# %%
AV_API_URL = "https://www.alphavantage.co/query"
parameters = {
    "function": "CRYPTO_INTRADAY",
    "symbol": "ETH",
    "market": "USD",
    "interval": "30min",
    "outputsize": "full",
    "apikey": "DJU7G3TSMOLW0H25"
}
r = requests.get(AV_API_URL, params=parameters)
data = r.json()

# Check if the API returned an error message instead of data
if "Information" in data:
    print(f"API Error: {data['Information']}")
    df = pd.DataFrame() # Create an empty DataFrame or handle the error as appropriate
elif "Time Series Crypto (30min)" in data:
    df = (
        pd.DataFrame(data["Time Series Crypto (30min)"])
        .transpose()
    )
else:
    print("Unexpected API response format.")
    df = pd.DataFrame()

df
# Out:
# API Error: Thank you for using Alpha Vantage! This is a premium endpoint. You may subscribe to any of the premium plans at https://www.alphavantage.co/premium/ to instantly unlock all premium endpoints
# Empty DataFrame
# Columns: []
# Index: []

# %%
import yfinance as yf

btc_data = yf.download("BTC-USD", start="2020-01-01", end="2023-12-31")
display(btc_data.head())
# Out:
# /tmp/ipython-input-2599484688.py:3: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   btc_data = yf.download("BTC-USD", start="2020-01-01", end="2023-12-31")
# [*********************100%***********************]  1 of 1 completed
# Price             Close         High          Low         Open       Volume
# Ticker          BTC-USD      BTC-USD      BTC-USD      BTC-USD      BTC-USD
# Date
# 2020-01-01  7200.174316  7254.330566  7174.944336  7194.892090  18565664997
# 2020-01-02  6985.470215  7212.155273  6935.270020  7202.551270  20802083465
# 2020-01-03  7344.884277  7413.715332  6914.996094  6984.428711  28111481032
# 2020-01-04  7410.656738  7427.385742  7309.514160  7345.375488  18444271275
# 2020-01-05  7411.317383  7544.497070  7400.535645  7410.451660  19725074095

# %%
AV_API_URL = "https://www.alphavantage.co/query"
parameters = {
    "function": "EARNINGS_CALENDAR",
    "horizon": "3month",
    "apikey": "DJU7G3TSMOLW0H25"
}
r = requests.get(AV_API_URL, params=parameters)
pd.read_csv(BytesIO(r.content))
# Out:
#      symbol                       name  reportDate fiscalDateEnding  estimate  \
# 0       BKR  BAKER HUGHES CO - CLASS A  2026-01-25       2025-12-31    0.6700
# 1      AGNC       AGNC INVESTMENT CORP  2026-01-26       2025-12-31    0.3700
# 2      AGYS               AGILYSYS INC  2026-01-26       2025-12-31    0.3200
# 3     AKO-A  EMBOTELLADORA ANDINA S.A.  2026-01-26       2025-12-31    0.5627
# 4     ALPIB                      ALPIB  2026-01-26       2025-12-31       NaN
# ...     ...                        ...         ...              ...       ...
# 9675  SRRRF                      SRRRF  2026-04-24       2026-03-31       NaN
# 9676  TBXXF                      TBXXF  2026-04-24       2026-03-31    0.0900
# 9677  WAMFF                      WAMFF  2026-04-24       2026-03-31   -0.0100
# 9678  WDFCF                      WDFCF  2026-04-24       2026-03-31       NaN
# 9679  YGTFF                      YGTFF  2026-04-24       2026-03-31       NaN
#
#      currency timeOfTheDay
# ...

# %%
cg = CoinGeckoAPI()

# Get historical data for Bitcoin (BTC) against USD
# The from_timestamp and to_timestamp parameters expect Unix timestamps
end_date = datetime.now()
start_date = end_date.replace(year=end_date.year - 1) # Last 1 year of data

bits = cg.get_coin_market_chart_range_by_id(
    id='bitcoin',
    vs_currency='usd',
    from_timestamp=start_date.timestamp(),
    to_timestamp=end_date.timestamp()
)

# Convert prices to a pandas DataFrame
bits_df = pd.DataFrame(bits['prices'], columns=['Timestamp', 'Price'])
bits_df['Date'] = pd.to_datetime(bits_df['Timestamp'], unit='ms')
bits_df = bits_df.set_index('Date').drop('Timestamp', axis=1)

print(f"Downloaded {len(bits_df)} historical Bitcoin prices.")
display(bits_df.head())

# %%
# !pip install pycoingecko

# %%
from pycoingecko import CoinGeckoAPI
from datetime import datetime
import pandas as pd

# %%
cg = CoinGeckoAPI()

# %%
ohlc = cg.get_coin_ohlc_by_id(
    id="bitcoin", vs_currency="usd", days="14"
)
ohlc_df = pd.DataFrame(ohlc)
ohlc_df.columns = ["date", "open", "high", "low", "close"]
ohlc_df["date"] = pd.to_datetime(ohlc_df["date"], unit="ms")
ohlc_df
# Out:
#                   date     open     high      low    close
# 0  2026-01-12 00:00:00  90569.0  90819.0  90245.0  90819.0
# 1  2026-01-12 04:00:00  90868.0  92356.0  90694.0  91818.0
# 2  2026-01-12 08:00:00  91684.0  92128.0  91283.0  91283.0
# 3  2026-01-12 12:00:00  91287.0  91425.0  90311.0  90562.0
# 4  2026-01-12 16:00:00  90521.0  91446.0  90129.0  91446.0
# ..                 ...      ...      ...      ...      ...
# 79 2026-01-25 04:00:00  89097.0  89168.0  88740.0  88746.0
# 80 2026-01-25 08:00:00  88825.0  88940.0  88545.0  88545.0
# 81 2026-01-25 12:00:00  88543.0  88601.0  88120.0  88413.0
# 82 2026-01-25 16:00:00  88393.0  88801.0  88314.0  88314.0
# 83 2026-01-25 20:00:00  88317.0  88317.0  86386.0  86395.0
#
# [84 rows x 5 columns]

# %%
trending_coins = cg.get_search_trending()
(
    pd.DataFrame([coin["item"] for coin in trending_coins["coins"]])
    .drop(columns=["thumb", "small", "large"])
)
# Out:
#                      id  coin_id                 name   symbol  \
# 0               caldera    54475              Caldera      ERA
# 1                 river    69318                River    RIVER
# 2               bitcoin        1              Bitcoin      BTC
# 3              pax-gold     9519             PAX Gold     PAXG
# 4                seeker    70974               Seeker      SKR
# 5   nietzschean-penguin    71738  Nietzschean Penguin  PENGUIN
# 6        kinesis-silver    29789       Kinesis Silver      KAG
# 7           tether-gold    10481          Tether Gold     XAUT
# 8                solana     4128               Solana      SOL
# 9        pudgy-penguins    52622       Pudgy Penguins    PENGU
# 10               monero       69               Monero      XMR
# 11              lighter    71121              Lighter      LIT
# 12               nomina    69687               Nomina      NOM
# 13         dusk-network     5217                 DUSK     DUSK
# ...

# %%
cg.get_price(ids="bitcoin", vs_currencies="usd")
# Out:
# {'bitcoin': {'usd': 86562}}
